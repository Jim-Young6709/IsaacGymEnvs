# %% [markdown]
# # RL Side

# %% [markdown]
# ### test

# %% [markdown]
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# export grasp_type="left"
# export w_hand_orientation=2.0
# export w_hand_obj=1.0
# export w_curl=0.2
# export beta_hand_obj=6.0
# export use_bbox=True
# export grasp_z_scale=0.25
# export tolerance_name="0.005to0.01"
#
# python isaacgymenvs/train.py \
#   task=DexExpTableSide \
#   num_envs=4 \
#   seed=-1 \
#   train.params.config.minibatch_size=16 \
#   train.params.config.central_value_config.minibatch_size=16 \
#   seed=-1 \
#   headless=False \
#   wandb_activate=False \
#   wandb_group=dexgymNewSide \
#   task.env.enableDebugVis=True \
#   task.env.episodeLength=100 \
#   task.env.video_logging.capture=False \
#   task.env.video_logging.envs=64 \
#   task.task.randomize=True \
#   task.env.object_teleport.enable=False \
#   task.env.mesh.mesh_dir=./meshes_side/long \
#   task.env.grasp_guide_idx=1 \
#   task.env.log_per_object_success.capture=True \
#   task.reward.weights.w_hand_orientation=${w_hand_orientation} \
#   task.reward.weights.w_hand_obj=${w_hand_obj} \
#   task.reward.weights.w_curl=${w_curl} \
#   task.reward.exp.beta_hand_object=${beta_hand_obj} \
#   task.reward.params.grasp_on_object_z_height_tolerance=[0.015,0.03] \
#   task.env.object_settings.object_grasp_target_z_scale=${grasp_z_scale} \
#   task.observation.usage.use_z=${use_bbox} \
#   task.observation.usage.use_xy=${use_bbox} \
#   task.env.eef_init.side_mode=${grasp_type} \
#   task.env.eef_init.pose_bank_size=256 \
#   experiment="rel_gate_wcurl${w_curl}_graspzscale${grasp_z_scale}_bbox${use_bbox}_tolerance${tolerance_name}_${grasp_type}"
#
#
# num_envs=69 \
# seed=-1 \
# train.params.config.minibatch_size=276 \
# train.params.config.central_value_config.minibatch_size=276 \

# %% [markdown]
# ### no gate lift & to-goal reduce

# %% [markdown]
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# export grasp_type="left"
# export n=5.0
#
# export beta_hand_object=4.0
# export w_hand_obj=2.0
# export w_curl=0.8
# export w_lift=$(awk "BEGIN {print 0.2 * $n}")
# export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
# export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
# export use_midheight=True
# export mass_range="0.1_0.9"
# export mode="old_targetquat"
# export lie_flat_prob=0.0
# export grasp_guide_idx=3
#
# python isaacgymenvs/train.py \
#   task=DexExpTableSide \
#   num_envs=12288 \
#   seed=-1 \
#   headless=True \
#   checkpoint=runs/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_07-20-10-15/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1400_rew_2971.5508.pth \
#   wandb_activate=True \
#   wandb_group=dexgymNewSide \
#   task.env.enableDebugVis=False \
#   task.env.video_logging.capture=True \
#   task.env.video_logging.envs=16 \
#   task.task.randomize=True \
#   task.env.object_teleport.enable=False \
#   task.env.object_teleport.mode=fixed_prob \
#   task.env.mesh.mesh_dir=./meshes_side/long \
#   task.env.grasp_guide_idx=${grasp_guide_idx} \
#   task.env.log_per_object_success.capture=False \
#   task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#   task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#   task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#   task.env.object_settings.object_grasp_target_z_scale=0.25 \
#   task.env.object_wrench.horizontal_away_from_eef.enable=True \
#   task.env.object_wrench.vertical_downward.enable=True \
#   task.reward.params.resample_target_on_success=True \
#   task.reward.params.orientation_reward_mode=${mode} \
#   task.reward.weights.w_curl=${w_curl} \
#   task.reward.weights.w_lift=${w_lift} \
#   task.reward.weights.w_obj_goal=${w_obj_goal} \
#   task.reward.weights.w_success_bonus=${w_success_bonus} \
#   task.reward.exp.beta_hand_object=${beta_hand_object} \
#   task.reward.weights.w_hand_obj=${w_hand_obj} \
#   task.env.eef_init.side_mode=${grasp_type} \
#   task.env.eef_init.wrong_side_sample_prob=0.2 \
#   experiment="rel_curr_midheight${use_midheight}x${n}_mass${mass_range}_${mode}_curl${grasp_guide_idx}_${w_curl}_flat${lie_flat_prob}_full"
#
#
# checkpoint=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_object_axis_curl3_flat1.0_recovery0.25_04-16-06-05/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_object_axis_curl3_flat1.0_recovery0.25_ep_4600_rew_3359.5474.pth \
#
# checkpoint=runs/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_07-20-10-15/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1400_rew_2971.5508.pth \
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# export grasp_type="left"
# export n=10.0
#
# export beta_hand_object=4.0
# export w_hand_obj=2.0
# export w_curl=0.5
# export flat_side_recovery_prob=0.0
# export w_lift=$(awk "BEGIN {print 0.2 * $n}")
# export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
# export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
# export use_midheight=True
# export mass_range="0.1_0.9"
# export mode="object_axis"
# export lie_flat_prob=1.0
# export grasp_guide_idx=3
#
# python isaacgymenvs/train.py \
#   task=DexExpTableSide \
#   num_envs=12288 \
#   seed=-1 \
#   headless=True \
#   wandb_activate=True \
#   wandb_group=dexgymNewSide \
#   task.env.enableDebugVis=False \
#   task.env.video_logging.capture=True \
#   task.env.video_logging.envs=16 \
#   task.task.randomize=True \
#   task.env.object_teleport.enable=False \
#   task.env.object_teleport.mode=fixed_prob \
#   task.env.eef_init.flat_side_recovery_prob=${flat_side_recovery_prob} \
#   task.env.mesh.mesh_dir=./meshes_side/long \
#   task.env.grasp_guide_idx=${grasp_guide_idx} \
#   task.env.log_per_object_success.capture=True \
#   task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#   task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#   task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#   task.env.object_settings.object_grasp_target_z_scale=0.4 \
#    task.env.object_wrench.horizontal_away_from_eef.enable=False \
#   task.env.object_wrench.vertical_downward.enable=True \
#   task.env.object_wrench.vertical_downward.force_range="[2.0, 2.5]"
#   task.reward.params.resample_target_on_success=True \
#   task.reward.params.orientation_reward_mode=${mode} \
#   task.reward.weights.w_curl=${w_curl} \
#   task.reward.weights.w_lift=${w_lift} \
#   task.reward.weights.w_obj_goal=${w_obj_goal} \
#   task.reward.weights.w_success_bonus=${w_success_bonus} \
#   task.reward.exp.beta_hand_object=${beta_hand_object} \
#   task.reward.weights.w_hand_obj=${w_hand_obj} \
#   task.env.eef_init.side_mode=${grasp_type} \
#   experiment="rel_curr_midheight${use_midheight}x${n}_mass${mass_range}_${mode}_curl${grasp_guide_idx}_flat${lie_flat_prob}_recovery${flat_side_recovery_prob}"
#
#
#
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# export grasp_type="left"
# export n=10.0
#
# export beta_hand_object=4.0
# export w_hand_obj=2.0
# export w_curl=0.8
# export w_lift=$(awk "BEGIN {print 0.2 * $n}")
# export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
# export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
# export use_midheight=True
# export mass_range="0.9_0.9"
# export mode="old_targetquat"
# export lie_flat_prob=0.0
# export grasp_guide_idx=3
#
# python isaacgymenvs/train.py \
#   task=DexExpTableSide \
#   num_envs=4 \
#   seed=-1 \
#   train.params.config.minibatch_size=16 \
#   train.params.config.central_value_config.minibatch_size=16 \
#   checkpoint=/home/rayliu/grogu/IsaacGymEnvs/runs/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_06-16-26-00/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_2200_rew_3525.8923.pth \
#   headless=False \
#   wandb_activate=False \
#   wandb_group=dexgymNewSide \
#   task.env.enableDebugVis=True \
#   task.env.video_logging.capture=False \
#   task.env.video_logging.envs=64 \
#   task.task.randomize=True \
#   task.env.object_teleport.enable=False \
#   task.env.mesh.mesh_dir=./meshes_side/long \
#   task.env.grasp_guide_idx=${grasp_guide_idx} \
#   task.env.log_per_object_success.capture=True \
#   task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#   task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#   task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#   task.env.object_settings.object_grasp_target_z_scale=0.25 \
#   task.env.object_wrench.horizontal_away_from_eef.enable=True \
#   task.env.object_wrench.vertical_downward.enable=True \
#   task.reward.params.resample_target_on_success=True \
#   task.reward.params.orientation_reward_mode=${mode} \
#   task.reward.weights.w_curl=${w_curl} \
#   task.reward.weights.w_lift=${w_lift} \
#   task.reward.weights.w_obj_goal=${w_obj_goal} \
#   task.reward.weights.w_success_bonus=${w_success_bonus} \
#   task.reward.exp.beta_hand_object=${beta_hand_object} \
#   task.reward.weights.w_hand_obj=${w_hand_obj} \
#   task.env.eef_init.side_mode=${grasp_type} \
#   experiment="rel_curr_midheight${use_midheight}x${n}_mass${mass_range}_${mode}_curl${grasp_guide_idx}_${w_curl}_flat${lie_flat_prob}"
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# export grasp_type="left"
# export n=10.0
#
# export beta_hand_object=4.0
# export w_hand_obj=2.0
# export w_curl=0.5
# export flat_side_recovery_prob=0.0
# export w_lift=$(awk "BEGIN {print 0.2 * $n}")
# export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
# export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
# export use_midheight=False
# export mass_range="0.1_0.9"
# export mode="object_axis"
# export lie_flat_prob=1.0
# export grasp_guide_idx=3
#
# python isaacgymenvs/train.py \
#   task=DexExpTableSide \
#   num_envs=4 \
#   seed=-1 \
#   train.params.config.minibatch_size=16 \
#   train.params.config.central_value_config.minibatch_size=16 \
#   headless=False \
#   checkpoint=/home/rayliu/grogu/IsaacGymEnvs/runs/FrankaLEAPPickTable_07-20-10-55/nn/last_FrankaLEAPPickTable_ep_6000_rew_3129.4106.pth \
#   wandb_activate=False \
#   wandb_group=dexgymNewSide \
#   task.env.enableDebugVis=True \
#   task.env.video_logging.capture=False \
#   task.env.video_logging.envs=64 \
#   task.task.randomize=True \
#   task.env.object_teleport.enable=True \
#   task.env.object_teleport.mode=fixed_prob \
#   task.env.eef_init.flat_side_recovery_prob=${flat_side_recovery_prob} \
#   task.env.mesh.mesh_dir=./meshes_side/long \
#   task.env.grasp_guide_idx=${grasp_guide_idx} \
#   task.env.log_per_object_success.capture=True \
#   task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#   task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#   task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#   task.env.object_settings.object_grasp_target_z_scale=0.4 \
#   task.env.object_wrench.horizontal_away_from_eef.enable=True \
#   task.env.object_wrench.vertical_downward.enable=True \
#   task.reward.params.resample_target_on_success=True \
#   task.reward.params.orientation_reward_mode=${mode} \
#   task.reward.weights.w_curl=${w_curl} \
#   task.reward.weights.w_lift=${w_lift} \
#   task.reward.weights.w_obj_goal=${w_obj_goal} \
#   task.reward.weights.w_success_bonus=${w_success_bonus} \
#   task.reward.exp.beta_hand_object=${beta_hand_object} \
#   task.reward.weights.w_hand_obj=${w_hand_obj} \
#   task.env.eef_init.side_mode=${grasp_type} \
#   experiment="rel_curr_midheight${use_midheight}x${n}_mass${mass_range}_${mode}_curl${grasp_guide_idx}_flat${lie_flat_prob}"

# %% [markdown]
# # RL last

# %% [markdown]
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
#   export WANDB_API_KEY="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"
#
#   export grasp_type="left"
#   export n=10.0
#
#   export beta_hand_object=4.0
#   export w_hand_obj=2.0
#   export w_curl=0.8
#   export w_lift=$(awk "BEGIN {print 0.2 * $n}")
#   export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
#   export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
#   export use_midheight=True
#   export mass_range="0.1_0.9"
#   export mode="old_targetquat"
#   export lie_flat_prob=0.0
#   export grasp_guide_idx=3
#
#   python isaacgymenvs/train.py \
#     task=DexExpTableSideCopy \
#     num_envs=2048 \
#     seed=-1 \
#     headless=True \
#     wandb_activate=True \
#     wandb_group=dexgymNewSide \
#     task.env.enableDebugVis=False \
#     task.env.video_logging.capture=True \
#     task.env.video_logging.envs=64 \
#     task.task.randomize=True \
#     task.env.object_teleport.enable=False \
#     task.env.mesh.mesh_dir=./meshes_side/long \
#     task.env.grasp_guide_idx=${grasp_guide_idx} \
#     task.env.log_per_object_success.capture=False \
#     task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#     task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#     task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#     task.env.object_settings.object_grasp_target_z_scale=0.25 \
#     task.env.object_wrench.horizontal_away_from_eef.enable=True \
#     task.env.object_wrench.vertical_downward.enable=True \
#     task.reward.params.resample_target_on_success=True \
#     task.reward.params.orientation_reward_mode=${mode} \
#     task.reward.weights.w_curl=${w_curl} \
#     task.reward.weights.w_lift=${w_lift} \
#     task.reward.weights.w_obj_goal=${w_obj_goal} \
#     task.reward.weights.w_success_bonus=${w_success_bonus} \
#     task.reward.exp.beta_hand_object=${beta_hand_object} \
#     task.reward.weights.w_hand_obj=${w_hand_obj} \
#     task.env.eef_init.side_mode=${grasp_type} \
#     task.env.scene.teacher_bank_variation_json=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_2/side_training_variations.json \
#     task.env.activation_snapshot_bank.enable=True \
#     task.env.activation_snapshot_bank.hdf5_path=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_2/run_1/side_activation_snapshots_merged.hdf5 \
#     task.env.activation_snapshot_bank.sampling_probs.afar=1.0 \
#     task.env.activation_snapshot_bank.sampling_probs.near_recovery=0.0 \
#     task.env.activation_snapshot_bank.sampling_probs.far_recovery=0.0 \
#     experiment="snapshot_smoke_side_copy_afar_only"
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
#   export WANDB_API_KEY="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"
#
#   export grasp_type="left"
#   export n=10.0
#
#   export beta_hand_object=4.0
#   export w_hand_obj=2.0
#   export w_curl=0.8
#   export w_lift=$(awk "BEGIN {print 0.2 * $n}")
#   export w_obj_goal=$(awk "BEGIN {print 0.4 * $n}")
#   export w_success_bonus=$(awk "BEGIN {print 0.1 * $n}")
#   export use_midheight=True
#   export mass_range="0.1_0.9"
#   export mode="old_targetquat"
#   export lie_flat_prob=0.0
#   export grasp_guide_idx=3
#
#   python isaacgymenvs/train.py \
#     task=DexExpTableSideCopy \
#     num_envs=4 \
#     seed=-1 \
#     checkpoint=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_04-18-29-00/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1800_rew_4092.7595.pth \
#     train.params.config.minibatch_size=16 \
#     train.params.config.central_value_config.minibatch_size=16 \
#     headless=False \
#     wandb_activate=False \
#     wandb_group=dexgymNewSide \
#     task.env.enableDebugVis=True \
#     task.env.video_logging.capture=False \
#     task.env.video_logging.envs=64 \
#     task.task.randomize=True \
#     task.env.object_teleport.enable=False \
#     task.env.mesh.mesh_dir=./meshes_side/long \
#     task.env.grasp_guide_idx=${grasp_guide_idx} \
#     task.env.log_per_object_success.capture=True \
#     task.reward.params.hand_obj_use_midheight_xy=${use_midheight} \
#     task.env.object_settings.mass_range="[${mass_range/_/, }]" \
#     task.env.object_settings.lie_flat_prob=${lie_flat_prob} \
#     task.env.object_settings.object_grasp_target_z_scale=0.25 \
#     task.env.object_wrench.horizontal_away_from_eef.enable=False \
#     task.env.object_wrench.vertical_downward.enable=False \
#     task.reward.params.resample_target_on_success=True \
#     task.reward.params.orientation_reward_mode=${mode} \
#     task.reward.weights.w_curl=${w_curl} \
#     task.reward.weights.w_lift=${w_lift} \
#     task.reward.weights.w_obj_goal=${w_obj_goal} \
#     task.reward.weights.w_success_bonus=${w_success_bonus} \
#     task.reward.exp.beta_hand_object=${beta_hand_object} \
#     task.reward.weights.w_hand_obj=${w_hand_obj} \
#     task.env.eef_init.side_mode=${grasp_type} \
#     task.env.activation_snapshot_bank.enable=True \
#     task.env.scene.teacher_bank_variation_json=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_3/run_1/side_training_variations_first4.json \
#     task.env.activation_snapshot_bank.hdf5_path=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_3/run_1/side_activation_snapshots_merged.hdf5 \
#     experiment="snapshot_smoke_side_copy_debug4"

# %% [markdown]
# # Eval

# %% [markdown]
#   export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
#   export WANDB_API_KEY="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"
#
#   torchrun --nnodes=1 --nproc_per_node=8 --master_port=29501 \
#       isaacgymenvs/distillation/run_dagger.py \
#       task=DexMobileDistillationSide \
#       num_envs=1024 \
#       seed=1 \
#       multi_gpu=True \
#       headless=True \
#       wandb_activate=True \
#       wandb_group=dexgymNewSide \
#       dagger.teacher_eval_only=True \
#       task.env.video_logging.capture=False \
#       task.env.video_logging.envs=16 \
#       teacher.ckpt=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_04-18-29-00/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1800_rew_4092.7595.pth \
#       task.task.randomize=True \
#       "task.env.object_settings.mass_range=[0.2, 0.8]" \
#       task.env.object_teleport.enable=True \
#       task.env.object_teleport.success_curriculum.start_stage=10 \
#       task.env.teacher_obs_action_frame=eef \
#       task.env.enableDebugVis=False \
#       task.env.enable_viser=False \
#       task.env.mesh.mesh_dir=./meshes_side/long \
#       task.env.grasp_guide_idx=1 \
#       task.env.scene.teacher_bank_height_bins=0 \
#       task.env.scene.teacher_bank_variation_json=/home/muxinl/IsaacGymEnvs/teacher_state_bank_3/side_generation_variations.json \
#       task.env.verified_teacher_bank.enable=True \
#       task.env.verified_teacher_bank.hdf5_path=/home/muxinl/IsaacGymEnvs/teacher_state_bank_3/run_mixed_1/side_verified_teacher_states.hdf5 \
#       task.env.verified_teacher_bank.capacity_per_env=32 \
#       task.env.verified_teacher_bank.collection_region_filter=all \
#       task.env.verified_teacher_bank.sampling_probs.afar=0.3333 \
#       task.env.verified_teacher_bank.sampling_probs.near_recovery=0.3333 \
#       task.env.verified_teacher_bank.sampling_probs.far_recovery=0.3334 \
#       model=transformer_mobile_local_t_auxdelta \
#       dagger.learning_rate=1e-4 \
#       chunk_size=1 \
#       dagger.eval_freq=0 \
#       dagger.teacher_forcing.enable=True \
#       experiment=teacher_bank3_mixed_1_teacher_eval
#
#
#  export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
#   export WANDB_API_KEY="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"
#
#   torchrun --nnodes=1 --nproc_per_node=2 --master_port=29501 \
#       isaacgymenvs/distillation/run_dagger.py \
#       task=DexMobileDistillationTopLong \
#       num_envs=1024 \
#       seed=1 \
#       multi_gpu=True \
#       headless=True \
#       wandb_activate=True \
#       wandb_group=dexgymNewTopLong \
#       dagger.teacher_eval_only=True \
#       task.env.video_logging.capture=False \
#       teacher.ckpt=runs/FrankaLEAPPickTable_07-20-10-55/nn/last_FrankaLEAPPickTable_ep_6000_rew_3129.4106.pth \
#       task.task.randomize=True \
#       "task.env.object_settings.mass_range=[0.2, 0.8]" \
#       task.env.object_teleport.enable=False \
#       task.env.object_wrench.enable=True \
#       task.env.object_wrench.success_curriculum.enable=False \
#       task.env.object_wrench.curri_steps=1 \
#       task.env.teacher_obs_action_frame=eef \
#       task.env.enableDebugVis=False \
#       task.env.enable_viser=False \
#       task.env.mesh.mesh_dir=./meshes_side/long \
#       task.env.grasp_guide_idx=1 \
#       task.env.verified_teacher_bank.enable=False \
#       model=transformer_mobile_local_t_auxdelta \
#       dagger.learning_rate=1e-4 \
#       chunk_size=1 \
#       dagger.eval_freq=0 \
#       dagger.teacher_forcing.enable=True \
#       experiment=top_long_teacher_eval_only

# %% [markdown]
# # Distillation Side

# %% [markdown]
# python3 /home/rayliu/run-orchestrator/bin/grogu_autorecover.py \
#     --name dexmobile_dagger_side_left_canonical_robust_$(date +%s) \
#     --script-file /home/rayliu/run-orchestrator/workspace/left_canonical_robust.remote.sh \
#     --node 2-3 \
#     --preferred-gpu-types A5000,A6000,rtx6000 \
#     --required-gpus 8 \
#     --cpus-per-task 128 \
#     --mem 890G \
#     --time-limit 48:00:00 \
#     --checkpoint-strategy dagger_latest \
#     --recovery-mode realloc \
#     --recovery-strategy auto \
#     --max-recovery-attempts 10
#
# python3 /home/rayliu/run-orchestrator/bin/grogu_autorecover.py \
#     --name dexmobile_dagger_side_left_canonical_robust_1777123415 \
#     --attach-existing \
#     --recover-now \
#     --node 2-3 \
#     --preferred-gpu-types A5000,A6000 \
#     --required-gpus 8 \
#     --cpus-per-task 128 \
#     --mem 880G \
#     --time-limit 48:00:00 \
#     --checkpoint-strategy dagger_latest \
#     --recovery-mode realloc \
#     --recovery-strategy fallback \
#     --max-recovery-attempts 10
#
#
# python3 /home/rayliu/run-orchestrator/bin/grogu_autorecover.py \
#     --name dexmobile_dagger_top_long$(date +%s) \
#     --script-file /home/rayliu/run-orchestrator/workspace/top_long.remote.sh \
#     --node 1-19 \
#     --preferred-gpu-types A5000,A6000 \
#     --required-gpus 8 \
#     --cpus-per-task 76 \
#     --mem 345G \
#     --time-limit 48:00:00 \
#     --checkpoint-strategy dagger_latest \
#     --recovery-mode realloc \
#     --recovery-strategy auto \
#     --max-recovery-attempts 10
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
# export WANDB_API_KEY="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"
#
# torchrun --nnodes=1 --nproc_per_node=1 --master_port=29501 \
# isaacgymenvs/distillation/run_dagger.py \
#     task=DexMobileDistillationTopLong \
#     num_envs=4 \
#     seed=1 \
#     multi_gpu=False \
#     headless=False \
#     wandb_activate=False \
#     wandb_group=dexgymNewTopLong \
#     task.env.video_logging.capture=False \
#     task.env.video_logging.envs=16 \
#     teacher.ckpt=/home/rayliu/grogu/IsaacGymEnvs/runs/FrankaLEAPPickTable_07-20-10-55/nn/last_FrankaLEAPPickTable_ep_6000_rew_3129.4106.pth \
#     task.task.randomize=True \
#     "task.env.object_settings.mass_range=[0.2, 0.8]" \
#     task.env.object_teleport.enable=True \
#     task.env.object_wrench.enable=True \
#     task.env.object_wrench.success_curriculum.enable=False \
#     task.env.object_wrench.curri_steps=1 \
#     task.env.teacher_obs_action_frame=eef \
#     task.env.enableDebugVis=True \
#     task.env.enable_viser=True \
#     task.env.mesh.mesh_dir=./meshes_side/long \
#     task.env.grasp_guide_idx=1 \
#     model=transformer_mobile_local_t_auxdelta \
#     dagger.learning_rate=1e-4 \
#     chunk_size=1 \
#     dagger.eval_freq=0 \
#     dagger.teacher_forcing.enable=True \
#     dagger.teacher_state_bank.collect_before_train=False \
#     dagger.teacher_state_bank.collect_only=False \
#     experiment=top_long
#
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
#   export WANDB_API_KEY="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"
#
#   torchrun --nnodes=1 --nproc_per_node=1 --master_port=29501 \
#       isaacgymenvs/distillation/run_dagger.py \
#       task=DexMobileDistillationSide \
#       num_envs=16 \
#       seed=1 \
#       multi_gpu=False \
#       headless=False \
#       wandb_activate=False \
#       wandb_group=dexgymNewSide \
#       task.env.video_logging.capture=False \
#       task.env.video_logging.envs=16 \
#       teacher.ckpt=/home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_04-18-29-00/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1800_rew_4092.7595.pth \
#       task.task.randomize=True \
#       task.env.scene.teacher_bank_variation_json=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_3/run_correct_only_3/failure_view_near16/side_training_variations_near_failure16.json \
#   task.env.verified_teacher_bank.enable=True \
#   task.env.verified_teacher_bank.hdf5_path=/home/rayliu/grogu/IsaacGymEnvs/teacher_state_bank_3/run_correct_only_3/failure_view_near16/side_verified_teacher_states_near_failure16.hdf5 \
#   task.env.verified_teacher_bank.capacity_per_env=32 \
#   task.env.verified_teacher_bank.sampling_probs.afar=0.0 \
#   task.env.verified_teacher_bank.sampling_probs.near_recovery=1.0 \
#   task.env.verified_teacher_bank.sampling_probs.far_recovery=0.0 \
#       "task.env.object_settings.mass_range=[0.2, 0.8]" \
#       task.env.object_teleport.enable=False \
#       task.env.teacher_obs_action_frame=eef \
#       task.env.enableDebugVis=True \
#       task.env.enable_viser=True \
#       task.env.mesh.mesh_dir=./meshes_side/long \
#       task.env.grasp_guide_idx=1 \
#       model=transformer_mobile_local_t_auxdelta \
#       dagger.learning_rate=1e-4 \
#       chunk_size=1 \
#       dagger.eval_freq=0 \
#       dagger.teacher_forcing.enable=True \
#       experiment=left_canonical_robust
#
#
#
#
#   export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
#
#
#
#
#
# good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_27-09-28-50/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_4800_rew_3990.5073.pth \
#
#
#   export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
#   export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
#   export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH:-}"
#   export WANDB_API_KEY="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"
#
#   torchrun --nnodes=1 --nproc_per_node=8 --master_port=29501 \
#       isaacgymenvs/distillation/run_dagger.py \
#       task=DexMobileDistillationSide \
#       num_envs=1024 \
#       seed=1 \
#       multi_gpu=True \
#       headless=True \
#       wandb_activate=False \
#       wandb_group=dexgymNewSide \
#       task.env.video_logging.capture=False \
#       task.env.video_logging.envs=16 \
#       teacher.ckpt=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_04-18-29-00/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_full_ep_1800_rew_4092.7595.pth \
#       task.task.randomize=True \
#       "task.env.object_settings.mass_range=[0.2, 0.8]" \
#       task.env.object_teleport.enable=False \
#       task.env.teacher_obs_action_frame=eef \
#       task.env.enableDebugVis=False \
#       task.env.enable_viser=False \
#       task.env.mesh.mesh_dir=./meshes_side/long \
#       task.env.grasp_guide_idx=1 \
#       task.env.scene.teacher_bank_height_bins=0 \
#       task.env.verified_teacher_bank.enable=True \
#       task.env.verified_teacher_bank.capacity_per_env=32 \
#       task.env.activation_snapshot_bank.enable=True \
#       task.env.scene.teacher_bank_variation_json=/home/muxinl/IsaacGymEnvs/teacher_state_bank_3/side_generation_variations.json \
#       task.env.verified_teacher_bank.collection_region_filter=all \
#       task.env.verified_teacher_bank.hdf5_path=/home/muxinl/IsaacGymEnvs/teacher_state_bank_3/run_mixed_1/side_verified_teacher_states.hdf5 \
#       task.env.activation_snapshot_bank.hdf5_path=/home/muxinl/IsaacGymEnvs/teacher_state_bank_3/run_mixed_1/side_activation_snapshots.hdf5 \
#       model=transformer_mobile_local_t_auxdelta \
#       dagger.learning_rate=1e-4 \
#       chunk_size=1 \
#       dagger.eval_freq=0 \
#       dagger.teacher_forcing.enable=True \
#       dagger.teacher_state_bank.collect_only=True \
#       dagger.teacher_state_bank.max_success_episodes_per_category=0 \
#       experiment=left_canonical_robust_collect
#
# task.env.verified_teacher_bank.collection_region_filter=correct_only \
#
#
#
#
#
#
#
#
#
#
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# torchrun --nnodes=1 --nproc_per_node=8 --master_port=29501 \
# isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=512 seed=1 multi_gpu=True headless=True wandb_activate=True wandb_group=dexgymNewSide task.env.video_logging.capture=True task.env.video_logging.envs=32 teacher.ckpt=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_23-21-39-24/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_ep_1200_rew_3823.4878.pth task.task.randomize=True "task.env.object_settings.mass_range=[0.2, 0.8]" task.env.object_teleport.enable=True task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=True task.env.enable_viser=True task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 model=transformer_mobile_local_t_auxdelta dagger.learning_rate=1e-4 chunk_size=1 dagger.eval_freq=10 dagger.teacher_forcing.enable=True experiment=left_canonical_robust
#
#
# export DUMP_INFERENCE_IO=0
# export DUMP_INFERENCE_IO_MAX=500
# export DUMP_INFERENCE_IO_ENV=0
# export DEBUG_REPLAY_SNAPSHOT_PATH=/home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/left_canonical_aux_03-23-47-20/debug_io_snapshots/debug_inference_io_pairs.pt
# export DEBUG_REPLAY_SNAPSHOT_MAX=500
# export DUMP_INFERENCE_IO_PATH=/home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/left_canonical_aux_03-23-47-20/debug_io_snapshots/debug_inference_io_pairs.pt
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# torchrun --nnodes=1 --nproc_per_node=1 --master_port=29501 \
# isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=32 seed=1 multi_gpu=True headless=False wandb_activate=False wandb_group=dexgymNewSide task.env.video_logging.capture=False task.env.video_logging.envs=32 teacher.ckpt=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_23-21-39-24/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_ep_1200_rew_3823.4878.pth task.task.randomize=True "task.env.object_settings.mass_range=[0.2, 0.8]" task.env.object_teleport.enable=True task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=True task.env.enable_viser=True task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 model=transformer_mobile_local_t_auxdelta dagger.learning_rate=1e-4 chunk_size=1 dagger.eval_freq=10 dagger.teacher_forcing.enable=True
#
# export DUMP_INFERENCE_IO=1
# export DUMP_INFERENCE_IO_MAX=10
# export DUMP_INFERENCE_IO_ENV=0
# export DUMP_INFERENCE_IO_PATH=/home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/left_canonical_aux_03-23-47-20/debug_io_snapshots
#
# python isaacgymenvs/inference/debug_compare_inference_io.py \
# --dump /home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/left_canonical_aux_03-23-47-20/debug_io_snapshots/debug_inference_io_pairs.pt \
# --ckpt /home/rayliu/grogu/IsaacGymEnvs/good_checkpoints/left_canonical_aux_03-23-47-20/latest.pt \
# --q-hand-delta-scale 1.0
#
# dagger.load_ckpt_path=good_checkpoints/rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_23-21-39-24/nn/last_rel_curr_midheightTruex10.0_mass0.1_0.9_old_targetquat_curl3_0.8_flat0.0_ep_1200_rew_3823.4878.pth
#
#
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# python isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=32 seed=1 multi_gpu=False headless=False wandb_activate=False wandb_group=dexgymNewSide task.env.video_logging.capture=False task.env.video_logging.envs=32 teacher.ckpt=runs/rel_curr_midheightFalsex4.0_mass0.2_1.5_left_26-02-05-12/nn/last_rel_curr_midheightFalsex4.0_mass0.2_1.5_left_ep_2000_rew_1429.8953.pth task.task.randomize=True "task.env.object_settings.mass_range=[0.2, 1.00]" task.env.object_teleport.enable=False task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=True task.env.enable_viser=False task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 model=transformer_mobile_local_t_auxdelta dagger.learning_rate=1e-4 chunk_size=10 dagger.eval_freq=10 dagger.teacher_forcing.enable=True experiment=left_canonical_aux_action_chunking
#
#
#
#
# export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# torchrun --nnodes=1 --nproc_per_node=2 --master_port=29501 \
# isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=512 seed=1 multi_gpu=True headless=True wandb_activate=True wandb_group=dexgymNewSide task.env.video_logging.capture=True task.env.video_logging.envs=64 teacher.ckpt=good_checkpoints/good_left_grasp_position_init_rand/nn/last_rel_side_gate_lift0.2_goal0.4_curl0.2_left_ep_2000_rew_1515.444.pth task.task.randomize=True task.env.object_teleport.enable=True task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=False task.env.enable_viser=False task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 task.observation.usage.use_z=True task.observation.usage.use_xy=True model=transformer_mobile_local_t dagger.learning_rate=1e-4 chunk_size=1 dagger.eval_freq=10 dagger.teacher_forcing.enable=True experiment=left_canonical_more_randomization
#
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
# export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# torchrun --nnodes=1 --nproc_per_node=8 --master_port=29501 \
# isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=512 seed=1 multi_gpu=True headless=True wandb_activate=True wandb_group=dexgymNewSide task.env.video_logging.capture=True task.env.video_logging.envs=32 teacher.ckpt=runs/rel_curr_midheightTruex4.0_mass0.2_0.75_left_13-16-25-28/nn/last_rel_curr_midheightTruex4.0_mass0.2_0.75_left_ep_3800_rew_1716.0946.pth task.task.randomize=True task.env.object_settings.mass_range="[0.2, 1.25]" task.env.object_teleport.enable=True task.env.object_teleport.force_right_of_eef=True task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=False task.env.enable_viser=False task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 model=transformer_mobile_local_t dagger.learning_rate=1e-4 chunk_size=1 dagger.eval_freq=10 dagger.teacher_forcing.enable=True experiment=left_canonical_more_randomization_mass_only_right
#
# isaacgymenvs/distillation/run_dagger.py task=DexMobileDistillationSide num_envs=512 seed=1 multi_gpu=True headless=True wandb_activate=True wandb_group=dexgymNewSide task.env.video_logging.capture=True task.env.video_logging.envs=32 teacher.ckpt=good_checkpoints/good_left_grasp_more_randomizations_mass/last_rel_midheightFalse_mass0.2_1.75_left_ep_33000_rew_1493.1493.pth task.task.randomize=True "task.env.object_settings.mass_range=[0.2, 1.25]" task.env.object_teleport.enable=True task.env.teacher_obs_action_frame=eef task.env.enableDebugVis=False task.env.enable_viser=False task.env.mesh.mesh_dir=./meshes_side/long task.env.grasp_guide_idx=1 model=transformer_mobile_local_t dagger.learning_rate=1e-4 chunk_size=1 dagger.eval_freq=10 dagger.teacher_forcing.enable=True experiment=left_canonical_more_randomization_mass

# %% [markdown]
# # Distillation Side Long

# %%
export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/isaacgym_urdf_overrides
export WARP_CACHE_ROOT=/home/muxinl/.cache/warp
export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
export WANDB_API_KEY="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"
torchrun --nnodes=1 --nproc_per_node=8 --master_port=29501 \
isaacgymenvs/distillation/run_dagger.py \
    task=DexMobileDistillationTopLong \
    num_envs=512 \
    seed=1 \
    multi_gpu=True \
    headless=True \
    wandb_activate=Tr \
    wandb_group=dexgymNewTopLong \
    task.env.video_logging.capture=True \
    task.env.video_logging.envs=32 \
    teacher.ckpt=good_checkpoints/rel_curr_midheightFalsex10.0_mass0.1_0.9_object_axis_curl3_flat1.0_23-18-07-52/nn/rel_curr_midheightFalsex10.0_mass0.1_0.9_object_axis_curl3_flat1.0.pth \
    task.task.randomize=True \
    "task.env.object_settings.mass_range=[0.2, 0.8]" \
    task.env.object_teleport.enable=True \
    task.env.object_wrench.enable=False \
    task.env.object_wrench.success_curriculum.enable=False \
    task.env.object_wrench.curri_steps=1 \
    task.env.teacher_obs_action_frame=eef \
    task.env.enableDebugVis=False \
    task.env.enable_viser=False \
    task.env.mesh.mesh_dir=./meshes_side/long \
    task.env.grasp_guide_idx=1 \
    model=transformer_mobile_local_t_auxdelta \
    dagger.learning_rate=1e-4 \
    chunk_size=1 \
    dagger.eval_freq=20 \
    dagger.teacher_forcing.enable=True \
    experiment=top_long




export ISAACGYM_URDF_CACHE_ROOT=/home/rayliu/.cache/isaacgym_urdf_overrides
export WARP_CACHE_ROOT=/home/rayliu/.cache/warp
export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
export WANDB_API_KEY="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"
torchrun --nnodes=1 --nproc_per_node=1 --master_port=29501 \
isaacgymenvs/distillation/run_dagger.py \
    task=DexMobileDistillationTopLong \
    num_envs=4 \
    seed=1 \
    multi_gpu=True \
    headless=False \
    wandb_activate=False \
    wandb_group=dexgymNewSide \
    task.env.video_logging.capture=False \
    task.env.video_logging.envs=32 \
    teacher.ckpt=good_checkpoints/rel_curr_midheightFalsex10.0_mass0.1_0.9_object_axis_curl3_flat1.0_23-18-07-52/nn/rel_curr_midheightFalsex10.0_mass0.1_0.9_object_axis_curl3_flat1.0.pth \
    "task.env.object_settings.mass_range=[0.5, 0.5]" \
    task.env.object_teleport.enable=False \
    task.env.object_wrench.enable=False \
    task.env.object_wrench.success_curriculum.enable=False \
    task.env.object_wrench.curri_steps=1 \
    task.env.teacher_obs_action_frame=eef \
    task.env.enableDebugVis=False \
    task.env.enable_viser=False \
    task.env.mesh.mesh_dir=./meshes_side/long \
    task.env.grasp_guide_idx=1 \
    model=transformer_mobile_local_t_auxdelta \
    dagger.learning_rate=1e-4 \
    chunk_size=1 \
    dagger.eval_freq=20 \
    dagger.teacher_forcing.enable=True

# %% [markdown]
# # Top Down Pinch

# %%
export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
export WANDB_API_KEY="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"
export use_palm=True
export pinch="full"
python isaacgymenvs/train.py task=DexExpTable num_envs=2 seed=-1 \
train.params.config.minibatch_size=8 \
train.params.config.central_value_config.minibatch_size=8 \
headless=False wandb_activate=False \
wandb_group=dexgymOGcurl2 \
task.env.enableDebugVis=True \
task.env.video_logging.capture=False \
task.task.randomize=True \
task.env.mesh.mesh_dir="./meshes_small/small" \
task.env.grasp_guide_idx=2 \
task.env.grasp_mode=${pinch} \
task.reward.params.include_palm_in_hand_obj=${use_palm} \
task.env.log_per_object_success.capture=True \
task.reward.usage.use_curl=True \
experiment=pinch



# before using this, note w_curl should be 0.5 by default
export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/meshes
export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
export WANDB_API_KEY="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"

export mass_range="0.3_0.3"
export use_palm=True
export pinch="full"

python isaacgymenvs/train.py task=DexExpTable num_envs=8192 seed=-1 \
headless=True wandb_activate=True \
wandb_group=dexgymPinch \
task.env.video_logging.capture=True \
task.env.video_logging.envs=64 \
task.task.randomize=True \
task.env.object_settings.mass_range="[${mass_range/_/, }]" \
task.env.mesh.mesh_dir="./meshes_small/small" \
task.env.grasp_guide_idx=2 \
task.env.grasp_mode=${pinch} \
task.reward.params.include_palm_in_hand_obj=${use_palm} \
task.env.log_per_object_success.capture=True \
task.reward.usage.use_curl=True \
task.reward.weights.w_curl=0.5 \
experiment=${pinch}_${use_palm}_forced_0.5

# %% [markdown]
# # Top Down

# %% [markdown]
# export ISAACGYM_URDF_CACHE_ROOT=/home/muxinl/.cache/meshes
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
#
# python isaacgymenvs/train.py task=DexExpTable num_envs=12288 seed=-1 \
# headless=True wandb_activate=True \
# wandb_group=dexgymTopdown \
# task.env.video_logging.capture=True \
# task.env.video_logging.envs=64 \
# task.task.randomize=True \
# task.env.object_settings.mass_range="[0.2, 1.5]" \
# task.env.mesh.mesh_dir="./meshes_69_new" \
# task.env.grasp_guide_idx=1 \
# task.env.grasp_mode=default \
# task.env.log_per_object_success.capture=True \
# task.reward.usage.use_curl=True \
# experiment=${pinch}_${use_palm}
#
#
#
#
#
# export LD_LIBRARY_PATH="$CONDA_PREFIX/lib:${LD_LIBRARY_PATH}"
# export WANDB_API_KEY="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"
# python isaacgymenvs/train.py task=DexExpTable num_envs=69 seed=-1 \
# train.params.config.minibatch_size=276 \
# train.params.config.central_value_config.minibatch_size=276 \
# headless=False wandb_activate=False \
# wandb_group=dexgymOGcurl2 \
# task.env.enableDebugVis=True \
# task.env.video_logging.capture=False \
# task.task.randomize=True \
# task.env.mesh.mesh_dir="./meshes_69_new" \
# task.env.grasp_guide_idx=1 \
# task.env.object_settings.scale_range="[1.0, 1.0]" \
# task.env.log_per_object_success.capture=True \
# task.reward.usage.use_curl=True \
# experiment=fancy_logging
